# %%
pwd
# Out:
# 'C:\\Users\\Aluno\\Desktop'

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
low_memory=False

# %matplotlib inline
pd.options.display.max_columns = 80
pd.options.display.max_rows = 90

# %%
producao = pd.ExcelFile('producao.xlsx')
arquivo = pd.read_excel(producao, sheet_name='CONTROLE')

# %%
arquivo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7424 entries, 0 to 7423
# Data columns (total 46 columns):
# QUADRO                764 non-null object
# OF                    7422 non-null object
# CLIENTE               7422 non-null object
# DESCRIÇÃO             7418 non-null object
# QTD:                  7416 non-null object
# DATA ABERTURA :       7269 non-null object
# PREVISÃO              7422 non-null object
# LEAD TIME             7396 non-null object
# ENTREGA               7424 non-null object
# DATA                  2308 non-null object
# DES:                  7401 non-null object
# P.O.:                 7408 non-null object
# MP                    2145 non-null object
# TORNO                 3223 non-null object
# FRESA                 3293 non-null object
# PROG.                 3183 non-null object
# CNC                   3297 non-null object
# AJUST                 3411 non-null object
# CTX                   202 non-null object
# ...

# %%
arquivo.query('ENTREGA == "NOK"')['P.O.:'].value_counts().sort_values().tail(10).plot(kind='barh',figsize=(10,10))

# %%
arquivo.query('ENTREGA == "NOK"')['P.O.:'].value_counts()
# Out:
# MT181022    98
# MT190200    51
# MT180310    36
# MT180313    35
# MT180309    20
# MT190299    20
# EN190694    20
# MT190319    20
# MT190403    19
# MT190430    12
# EN190704    10
# EN190731     6
# MT990000     6
# MT190429     5
# MT190004     5
# MT190528     4
# EN190668     4
# 990000       4
# EN190617     3
# MT180307     3
# EN190614     3
# EN190504     2
# MT190262     2
# EN190719     2
# EN190638     2
# EN190485     2
# MT190633     1
# EN190659     1
# MT190405     1
# EN190663     1
# EN17172      1
# EN190655     1
# MT180312     1
# EN190754     1
# EN190502     1
# EN190610     1
# EN190748     1
# EN190468     1
# MT190707     1
# EN190391     1
# MT181546     1
# EN190716     1
# EN190611     1
# EN190337     1
# MT190140     1
# MT190712     1
# EN190452     1
# MT190451     1
# EN190459     1
# MT190525     1
# EN190646     1
# EN190708     1
# MT181118     1
# MT181634     1
# EN190701     1
# MT190404     1
# EN190723     1
# EN190549     1
# ...

# %%
print('HORAS DE TORNO')
print(arquivo.query('ENTREGA == "NOK"')['TORNO'].sum()/60)
total=(arquivo.query('ENTREGA == "NOK"')['TORNO'].sum()/60)/8
print(f'O torno está ocupado por um total de {int(total)} dias')
# Out:
# HORAS DE TORNO
# 526.45
# O torno está ocupado por um total de 65 dias

# %%
print('HORAS DE FRESA')
arquivo.query('ENTREGA == "NOK"')['FRESA'].sum()/60
total=(arquivo.query('ENTREGA == "NOK"')['FRESA'].sum()/60)/8
print(f'A fresadora está ocupado por um total de {int(total)} dias')
# Out:
# HORAS DE FRESA
# A fresadora está ocupado por um total de 90 dias

# %%
print('HORAS DE PROGRAMAÇÃO')
arquivo.query('ENTREGA == "NOK"')['PROG.'].sum()/60
total=(arquivo.query('ENTREGA == "NOK"')['PROG.'].sum()/60)/8
print(f'A programação está ocupado por um total de {int(total)} dias')
# Out:
# HORAS DE PROGRAMAÇÃO
# A programação está ocupado por um total de 48 dias

# %%
print('HORAS DE AJUSTAGEM')
arquivo.query('ENTREGA == "NOK"')['AJUST'].sum()/60
total=(arquivo.query('ENTREGA == "NOK"')['AJUST'].sum()/60)/8
print(f'A Ajustagem está ocupado por um total de {int(total)} dias')
# Out:
# HORAS DE AJUSTAGEM
# A Ajustagem está ocupado por um total de 44 dias

# %%
print('HORAS DE CTX')
arquivo.query('ENTREGA == "NOK"')['CTX'].sum()/60
total=(arquivo.query('ENTREGA == "NOK"')['CTX'].sum()/60)/8
print(f'A CTX está ocupado por um total de {int(total)} dias')
# Out:
# HORAS DE CTX
# A CTX está ocupado por um total de 2 dias

# %%
print('HORAS DE SOLDA')
arquivo.query('ENTREGA == "NOK"')['SOLDA'].sum()/60
total=(arquivo.query('ENTREGA == "NOK"')['SOLDA'].sum()/60)/8
print(f'A Solda está ocupado por um total de {int(total)} dias')
# Out:
# HORAS DE SOLDA
# A Solda está ocupado por um total de 21 dias

# %%
print('HORAS DE TRATAMENTO SUPERFICIAL')
arquivo.query('ENTREGA == "NOK"')['T. SUP'].sum()/60
total=(arquivo.query('ENTREGA == "NOK"')['T. SUP'].sum()/60)/8
print(f'O tratamento superficial está ocupado por um total de {int(total)} dias')
# Out:
# HORAS DE TRATAMENTO SUPERFICIAL
# O tratamento superficial está ocupado por um total de 3 dias

# %%
print('HORAS DE MATÉRIA PRIMA')
arquivo.query('ENTREGA == "NOK"')['MP'].sum()/60
total=(arquivo.query('ENTREGA == "NOK"')['MP'].sum()/60)/8
print(f'A preparação de matéria prima está ocupado por um total de {int(total)} dias')
# Out:
# HORAS DE MATÉRIA PRIMA
# A preparação de matéria prima está ocupado por um total de 22 dias

# %%
print('HORAS DE RETIFICA/AFIAÇÃO')
arquivo.query('ENTREGA == "NOK"')['RETIF. / AFIA.'].sum()/60
total=(arquivo.query('ENTREGA == "NOK"')['RETIF. / AFIA.'].sum()/60)/8
print(f'A Retificadora e afiadora está ocupado por um total de {int(total)} dias')
# Out:
# HORAS DE RETIFICA/AFIAÇÃO
# A Retificadora e afiadora está ocupado por um total de 3 dias

# %%
print('HORAS DE PINTURA')
arquivo.query('ENTREGA == "NOK"')['PINT.'].sum()/60
total=(arquivo.query('ENTREGA == "NOK"')['PINT.'].sum()/60)/8
print(f'A Pintura está ocupado por um total de {int(total)} dias')
# Out:
# HORAS DE PINTURA
# A Pintura está ocupado por um total de 8 dias

# %%
print('HORAS DE PROJETO')
arquivo.query('ENTREGA == "NOK"')['PROJETO'].sum()/60
total=(arquivo.query('ENTREGA == "NOK"')['PROJETO'].sum()/60)/8
print(f'O projeto está ocupado por um total de {int(total)} dias')
# Out:
# HORAS DE PROJETO
# O projeto está ocupado por um total de 26 dias

# %%
print('HORAS DE INSPEÇÃO')
arquivo.query('ENTREGA == "NOK"')['INSP'].sum()/60
total=(arquivo.query('ENTREGA == "NOK"')['INSP'].sum()/60)/8
print(f'A Inspeção está ocupado por um total de {int(total)} dias')
# Out:
# HORAS DE INSPEÇÃO
# A Inspeção está ocupado por um total de 34 dias

# %%
s=arquivo.query('ENTREGA == "NOK"')['LEAD TIME'].value_counts().keys()

k={}
for lead,quant in arquivo.query('ENTREGA == "NOK"')['LEAD TIME'].value_counts().items():
    k[lead]=quant
h=[]
j=[]
c=0
for x in sorted(k):
    h.append(x)
    j.append(k[x])
    if x<1:
        c+=1

       
e=h[:c]
r=j[:c]

plt.bar(e,r,color='red')
plt.title('Peças atrasadas')
plt.xlabel('Lead Time')
plt.ylabel('Quantidade')
# Out:
# Text(0,0.5,'Quantidade')

# %%
arquivo.query('ENTREGA == "OK"')['P.O.:'].value_counts().sort_values().tail(10).plot(kind='barh',figsize=(5,5)).title('Maiores projetos entregues')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-82-de8a9dd6630e> in <module>()
# ----> 1 arquivo.query('ENTREGA == "OK"')['P.O.:'].value_counts().sort_values().tail(10).plot(kind='barh',figsize=(5,5)).title('Maiores projetos entregues')
#
# TypeError: 'Text' object is not callable
